# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load the data

# %%
df_2008=pd.read_csv('~/Desktop/desktop-tutorial/Week_11/Draft_Data/2008_draft.csv', header=1)
df_2009=pd.read_csv('~/Desktop/desktop-tutorial/Week_11/Draft_Data/2009_draft.csv', header=1)
df_2010=pd.read_csv('~/Desktop/desktop-tutorial/Week_11/Draft_Data/2010_draft.csv', header=1)
df_2011=pd.read_csv('~/Desktop/desktop-tutorial/Week_11/Draft_Data/2011_draft.csv', header=1)
df_2012=pd.read_csv('~/Desktop/desktop-tutorial/Week_11/Draft_Data/2012_draft.csv', header=1)
df_2013=pd.read_csv('~/Desktop/desktop-tutorial/Week_11/Draft_Data/2013_draft.csv', header=1)
df_2014=pd.read_csv('~/Desktop/desktop-tutorial/Week_11/Draft_Data/2014_draft.csv', header=0)

# %% [markdown]
# ## Data Cleaning and preparation

# %%
df_2008.head()
# Out:
#    Overall                 Team            Player Nat. Pos  Age      To  \
# 0        1  Tampa Bay Lightning    Steven Stamkos   CA   C   18  2023.0
# 1        2    Los Angeles Kings      Drew Doughty   CA   D   18  2023.0
# 2        3    Atlanta Thrashers     Zach Bogosian   US   D   18  2023.0
# 3        4      St. Louis Blues  Alex Pietrangelo   CA   D   18  2023.0
# 4        5  Toronto Maple Leafs       Luke Schenn   CA   D   18  2023.0
#
#            Junior Team League      GP  ...    PIM  Height  Weight  D0_GP  \
# 0        Sarnia Sting     OHL   942.0  ...  565.0    6′ 1     188     61
# 1        Guelph Storm     OHL  1038.0  ...  707.0    6′ 0     212     58
# 2  Peterborough Petes     OHL   740.0  ...  675.0    6′ 3     215     60
# 3     Niagara IceDogs     OHL   902.0  ...  303.0    6′ 3     206     60
# 4     Kelowna Rockets     WHL   885.0  ...  717.0    6′ 2     229     57
#
#    D0_G D0_A  D0_TP  D0_P/G  D0_PIM  D0_+/-
# 0    58   47    105    1.72      88    18.0
# ...

# %%
df_2008.columns
# Out:
# Index(['Overall', 'Team', 'Player', 'Nat.', 'Pos', 'Age', 'To', 'Junior Team',
#        'League', 'GP', 'G', 'A', 'PTS', '+/-', 'PIM', 'Height', 'Weight',
#        'D0_GP', 'D0_G', 'D0_A', 'D0_TP', 'D0_P/G', 'D0_PIM', 'D0_+/-'],
#       dtype='object')

# %%
# %store -r Point_df

# %%
df_2007 = Point_df
df_2007.head()
# Out:
#     Overall                 Team              Player Nat. Height Weight Pos  \
# 25        1   Chicago Blackhawks        Patrick Kane   US  5′ 10    178  RW
# 3         2  Philadelphia Flyers  James van Riemsdyk   US   6′ 3    200  LW
# 5         3      Phoenix Coyotes         Kyle Turris   CA   6′ 1    185   C
# 32        4    Los Angeles Kings       Thomas Hickey   CA  5′ 11    184   D
# 19        5  Washington Capitals         Karl Alzner   CA   6′ 3    206   D
#
#      Age      To                 Junior Team  ...   +/-    PIM  D0_GP  D0_G  \
# 25  18.0  2023.0             London Knights   ...  35.0  412.0     58    62
# 3   18.0  2023.0  USA U-18 Development Team   ... -65.0  352.0     30    20
# 5   18.0  2022.0                    Burnaby   ...  -7.0  343.0     53    66
# 32  18.0  2022.0       Seattle Thunderbirds   ...  37.0  190.0     68     9
# 19  18.0  2020.0             Calgary Hitmen   ...  54.0  219.0     63     8
#
#     D0_A  D0_TP  D0_P/G  D0_PIM  D0_+/-  level_0
# ...

# %%
df_2007 = df_2007[['Overall', 'Team', 'Player', 'Nat.', 'Pos', 'Age', 'To', 'Junior Team',
                   'League', 'GP', 'G', 'A', 'PTS', '+/-', 'PIM', 'Height', 'Weight',
                   'D0_GP', 'D0_G', 'D0_A', 'D0_TP', 'D0_P/G', 'D0_PIM', 'D0_+/-']]

# %%
# Look for missing values in each year's dataframe
df_2007.isnull().sum()
# Out:
# Overall         0
# Team            0
# Player          0
# Nat.            0
# Pos             0
# Age             1
# To             97
# Junior Team     0
# League          0
# GP             97
# G              97
# A              97
# PTS            97
# +/-            97
# PIM            97
# Height          0
# Weight          0
# D0_GP           0
# D0_G            0
# D0_A            0
# D0_TP           0
# D0_P/G          0
# D0_PIM          0
# D0_+/-          0
# dtype: int64

# %%
# Fill in missing age value with that specific player's age at the time of the draft
df_2007['Age']=df_2007['Age'].fillna(19)
# Out:
# /var/folders/cl/dg9768bj6ys0prn_4p_bbftw0000gn/T/ipykernel_15127/2707269856.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2007['Age']=df_2007['Age'].fillna(19)

# %%
df_2010[df_2010['Weight'].isnull()]
# Out:
#     Overall          Team             Player Nat. Pos  Age  To   Junior Team  \
# 72       77  Dallas Stars  Alexander Guptill   CA  LW   18 NaN  Orangeville
#
#    League  GP  ...  PIM  Height  Weight  D0_GP  D0_G D0_A  D0_TP  D0_P/G  \
# 72   OJHL NaN  ...  NaN  6′ 2.5     NaN     29    19   18     37    1.28
#
#     D0_PIM  D0_+/-
# 72      50      11
#
# [1 rows x 24 columns]

# %%
# Fill missing weight value with player's weight (found online)
df_2010['Weight'] = df_2010['Weight'].fillna(190)

# %%
df_2011.isnull().sum()
# Out:
# Overall         0
# Team            0
# Player          0
# Nat.            1
# Pos             1
# Age             1
# To             76
# Junior Team     1
# League          1
# GP             76
# G              76
# A              76
# PTS            76
# +/-            76
# PIM            76
# Height          1
# Weight          1
# D0_GP           1
# D0_G            1
# D0_A            1
# D0_TP           1
# D0_P/G          0
# D0_PIM          1
# D0_+/-          1
# dtype: int64

# %%
# Drop row belonging to forfeited pick
ind=df_2011[df_2011['Nat.'].isnull()].index
df_2011=df_2011.drop(ind)

# %%
df_2014.columns
# Out:
# Index(['Overall', 'Team', 'Player', 'Nat.', 'Pos', 'Age', 'To', 'Junior Team',
#        'League', 'GP', 'G', 'A', 'PTS', '+/-', 'PIM', 'Height', 'Weight',
#        'D0_GP', 'D0_G', 'D0_A', 'D0_TP', 'D0_P/G', 'D0_PIM', 'D0_+/-'],
#       dtype='object')

# %%
# Concatenate draft years creating one large dataframe

drafts = [df_2007, df_2008, df_2009,
          df_2010, df_2011, df_2012,
          df_2013, df_2014]

draft_db = pd.concat(drafts, axis=0)

# %%
draft_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1512 entries, 25 to 188
# Data columns (total 24 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Overall      1512 non-null   int64
#  1   Team         1512 non-null   object
#  2   Player       1512 non-null   object
#  3   Nat.         1512 non-null   object
#  4   Pos          1512 non-null   object
#  5   Age          1512 non-null   float64
#  6   To           786 non-null    float64
#  7   Junior Team  1512 non-null   object
#  8   League       1512 non-null   object
#  9   GP           786 non-null    float64
#  10  G            786 non-null    float64
#  11  A            786 non-null    float64
#  12  PTS          786 non-null    float64
#  13  +/-          786 non-null    float64
#  14  PIM          786 non-null    float64
#  15  Height       1512 non-null   object
#  16  Weight       1512 non-null   object
#  17  D0_GP        1512 non-null   object
# ...

# %% [markdown]
# ### Converting Data Columns into their appropriate type

# %%
draft_db['D0_PIM'] = draft_db['D0_PIM'].replace({'-': 0})
draft_db['D0_+/-'] = draft_db['D0_+/-'].replace({'-': 0})
draft_db['D0_GP'] = draft_db['D0_GP'].replace({'-': 0})
draft_db['D0_G'] = draft_db['D0_G'].replace({'-': 0})
draft_db['D0_A'] = draft_db['D0_A'].replace({'-': 0})
draft_db['D0_TP'] = draft_db['D0_TP'].replace({'-': 0})
draft_db['D0_P/G'] = draft_db['D0_P/G'].replace({'#VALUE!': 0})
draft_db['D0_P/G'] = draft_db['D0_P/G'].replace({'#DIV/0!': 0})

# %%
draft_db = draft_db.astype({'Weight': int,
                            'D0_GP': int,
                            'D0_G': int,
                            'D0_A': int,
                            'D0_TP': int,
                            'D0_P/G': float,
                            'D0_PIM': int,
                            'D0_+/-': float
                           }
                          )

# %% [markdown]
# ## Feature Engineering - NHLe

# %%
# Get a dataframe of only the players that made the NHL and played games
NHL_players = draft_db[draft_db['GP'].notna()]

# %%
NHL_players.head()
# Out:
#     Overall                 Team              Player Nat. Pos   Age      To  \
# 25        1   Chicago Blackhawks        Patrick Kane   US  RW  18.0  2023.0
# 3         2  Philadelphia Flyers  James van Riemsdyk   US  LW  18.0  2023.0
# 5         3      Phoenix Coyotes         Kyle Turris   CA   C  18.0  2022.0
# 32        4    Los Angeles Kings       Thomas Hickey   CA   D  18.0  2022.0
# 19        5  Washington Capitals         Karl Alzner   CA   D  18.0  2020.0
#
#                    Junior Team     League      GP  ...    PIM  Height  Weight  \
# 25             London Knights         OHL  1126.0  ...  412.0   5′ 10     178
# 3   USA U-18 Development Team   USDP/NAHL   885.0  ...  352.0    6′ 3     200
# 5                     Burnaby        BCHL   776.0  ...  343.0    6′ 1     185
# 32       Seattle Thunderbirds         WHL   456.0  ...  190.0   5′ 11     184
# 19             Calgary Hitmen         WHL   686.0  ...  219.0    6′ 3     206
#
# ...

# %%
NHL_players['League'].sort_values(ascending=True).unique()
# Out:
# array(['AHL', 'AJHL', 'BCHL', 'CCHA', 'CCHL', 'CHL T1', 'CJHL', 'Czech',
#        'Czech Jr.', 'ECAC', 'EJHL', 'Finland', 'Finland Jr.', 'Germany-2',
#        'H-East', 'High-CT', 'High-MA', 'High-MI', 'High-MN', 'High-NJ',
#        'High-ON', 'High-QC', 'KHL', 'MJHL', 'NAHL', 'Norway', 'OHL',
#        'OJHL', 'OPJHL', 'Ohio ', 'Ohio (CCHA', 'QMJHL', 'Russia',
#        'Russia Jr.', 'Russia-2', 'Russia-3', 'Slovakia', 'Slovakia-2',
#        'Sweden', 'Sweden Jr.', 'Sweden-2', 'Sweden-3', 'Swiss',
#        'USDP/NAHL', 'USDP/USHL', 'USHL', 'WCHA', 'WHL'], dtype=object)

# %%
# create a list of our conditions
conditions = [
    draft_db['League'] == 'AHL',
    draft_db['League'] == 'AJHL',
    draft_db['League'] == 'BCHL',
    draft_db['League'] == 'CCHA',
    draft_db['League'] == 'CCHL',
    draft_db['League'] == 'CHL T1',
    draft_db['League'] == 'CJHL',
    draft_db['League'] == 'Czech',
    draft_db['League'] == 'Czech Jr.',
    draft_db['League'] == 'ECAC',
    draft_db['League'] == 'EJHL',
    draft_db['League'] == 'Finland',
    draft_db['League'] == 'Finland Jr.',
    draft_db['League'] == 'Germany-2',
    draft_db['League'] == 'H-East',
    draft_db['League'] == 'High-CT',
    draft_db['League'] == 'High-MA',
    draft_db['League'] == 'High-MI',
    draft_db['League'] == 'High-MN',
    draft_db['League'] == 'High-NJ',
    draft_db['League'] == 'High-ON',
    draft_db['League'] == 'High-QC',
    draft_db['League'] == 'KHL',
    draft_db['League'] == 'MJHL',
    draft_db['League'] == 'NAHL',
    draft_db['League'] == 'Norway',
    draft_db['League'] == 'OHL',
    draft_db['League'] == 'OJHL',
    draft_db['League'] == 'OPJHL',
    draft_db['League'] == 'Ohio ',
    draft_db['League'] == 'Ohio (CCHA',
    draft_db['League'] == 'QMJHL',
    draft_db['League'] == 'Russia',
    draft_db['League'] == 'Russia Jr.',
    draft_db['League'] == 'Russia-2',
    draft_db['League'] == 'Russia-3',
    draft_db['League'] == 'Slovakia',
    draft_db['League'] == 'Slovakia-2',
    draft_db['League'] == 'Sweden',
    draft_db['League'] == 'Sweden Jr.',
    draft_db['League'] == 'Sweden-2',
    draft_db['League'] == 'Sweden-3',
    draft_db['League'] == 'Swiss',
    draft_db['League'] == 'USDP/NAHL',
    draft_db['League'] == 'USDP/USHL',
    draft_db['League'] == 'USHL',
    draft_db['League'] == 'WCHA',
    draft_db['League'] == 'WHL'
]

# create a list of the values we want to assign for each condition
values = [0.389, 0.064, 0.080,
          0.194, 0.048, 0.048,
          0.048, 0.583, 0.074,
          0.194, 0.060, 0.441,
          0.083, 0.205, 0.194,
          0.028, 0.028, 0.028,
          0.024, 0.028, 0.020,
          0.020, 0.772, 0.046,
          0.087, 0.173, 0.144,
          0.034, 0.034, 0.194,
          0.194, 0.113, 0.772,
          0.143, 0.328, 0.143,
          0.295, 0.102, 0.566,
          0.024, 0.351, 0.109,
          0.459, 0.121, 0.121,
          0.143, 0.194, 0.141]

# create a new column and use np.select to assign values to it using our lists as arguments
draft_db['NHLe Coefficient'] = np.select(conditions, values)

# display updated DataFrame
draft_db.head()
# Out:
#     Overall                 Team              Player Nat. Pos   Age      To  \
# 25        1   Chicago Blackhawks        Patrick Kane   US  RW  18.0  2023.0
# 3         2  Philadelphia Flyers  James van Riemsdyk   US  LW  18.0  2023.0
# 5         3      Phoenix Coyotes         Kyle Turris   CA   C  18.0  2022.0
# 32        4    Los Angeles Kings       Thomas Hickey   CA   D  18.0  2022.0
# 19        5  Washington Capitals         Karl Alzner   CA   D  18.0  2020.0
#
#                    Junior Team     League      GP  ...  Height  Weight  D0_GP  \
# 25             London Knights         OHL  1126.0  ...   5′ 10     178     58
# 3   USA U-18 Development Team   USDP/NAHL   885.0  ...    6′ 3     200     30
# 5                     Burnaby        BCHL   776.0  ...    6′ 1     185     53
# 32       Seattle Thunderbirds         WHL   456.0  ...   5′ 11     184     68
# 19             Calgary Hitmen         WHL   686.0  ...    6′ 3     206     63
#
# ...

# %%
draft_db['NHLe'] = draft_db['D0_P/G']*draft_db['NHLe Coefficient']*82

# %%
draft_db.head()
# Out:
#     Overall                 Team              Player Nat. Pos   Age      To  \
# 25        1   Chicago Blackhawks        Patrick Kane   US  RW  18.0  2023.0
# 3         2  Philadelphia Flyers  James van Riemsdyk   US  LW  18.0  2023.0
# 5         3      Phoenix Coyotes         Kyle Turris   CA   C  18.0  2022.0
# 32        4    Los Angeles Kings       Thomas Hickey   CA   D  18.0  2022.0
# 19        5  Washington Capitals         Karl Alzner   CA   D  18.0  2020.0
#
#                    Junior Team     League      GP  ...  Weight  D0_GP  D0_G  \
# 25             London Knights         OHL  1126.0  ...     178     58    62
# 3   USA U-18 Development Team   USDP/NAHL   885.0  ...     200     30    20
# 5                     Burnaby        BCHL   776.0  ...     185     53    66
# 32       Seattle Thunderbirds         WHL   456.0  ...     184     68     9
# 19             Calgary Hitmen         WHL   686.0  ...     206     63     8
#
# ...

# %%
draft_db.shape
# Out:
# (1512, 26)

# %%
# Create NHLer distinction column
draft_db.loc[draft_db['GP'] >= 200, 'NHLer'] = 1

# Fill null values with 0
draft_db['NHLer'] = draft_db['NHLer'].fillna(0)

# %%
draft_db.head(20)
# Out:
#     Overall                   Team              Player Nat.   Pos   Age  \
# 25        1     Chicago Blackhawks        Patrick Kane   US    RW  18.0
# 3         2    Philadelphia Flyers  James van Riemsdyk   US    LW  18.0
# 5         3        Phoenix Coyotes         Kyle Turris   CA     C  18.0
# 32        4      Los Angeles Kings       Thomas Hickey   CA     D  18.0
# 19        5    Washington Capitals         Karl Alzner   CA     D  18.0
# 28        6        Edmonton Oilers          Sam Gagner   CA     C  18.0
# 7         7  Columbus Blue Jackets       Jakub Voracek   CZ    RW  18.0
# 33        8          Boston Bruins         Zach Hamill   CA     C  18.0
# 15        9        San Jose Sharks       Logan Couture   CA     C  18.0
# 20       10       Florida Panthers      Keaton Ellerby   CA     D  18.0
# 1        11    Carolina Hurricanes      Brandon Sutter   US  C/RW  18.0
# 3        12     Montreal Canadiens       Ryan McDonagh   US     D  18.0
# ...

# %%
# %store draft_db
# Out:
# Stored 'draft_db' (DataFrame)
